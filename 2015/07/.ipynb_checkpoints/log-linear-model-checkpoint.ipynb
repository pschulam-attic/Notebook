# %%
import sys
sys.path.append('/Users/pschulam/Git/mypy')

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nips15
import online
import loglin
# %matplotlib inline

# %%
folds_dir = 'models/jmlr/folds'

def load_model(marker, fold, folds_dir=folds_dir):
    param_dir = os.path.join(folds_dir, marker, '{:02d}'.format(fold), 'param')
    return nips15.NipsModel.from_directory(param_dir)

# %%
demographic = ['female', 'afram']
molecular = ['aca', 'scl']

pfvc_spec = {'t':'years_seen_full', 'y':'pfvc', 'x1':demographic, 'x2':demographic + molecular}
pfvc = pd.read_csv('data/benchmark_pfvc.csv')
pfvc_pd = [nips15.PatientData.from_tbl(tbl, **pfvc_spec) for _, tbl in pfvc.groupby('ptid')]

tss_spec = {'t':'years_seen', 'y':'tss', 'x1':demographic, 'x2':demographic}
tss = pd.read_csv('data/benchmark_tss.csv')
tss_match = ['ptid'] + tss_spec['x1']
tss = pd.merge(pfvc[tss_match], tss, 'left', tss_match).drop_duplicates()
tss_pd = [nips15.PatientData.from_tbl(tbl, **tss_spec) for _, tbl in tss.groupby('ptid')]

pdlco_spec = {'t':'years_seen', 'y':'pdlco', 'x1':demographic, 'x2':demographic}
pdlco = pd.read_csv('data/benchmark_pdc.csv')
pdlco_match = ['ptid'] + pdlco_spec['x1']
pdlco = pd.merge(pfvc[pdlco_match], pdlco, 'left', pdlco_match).drop_duplicates()
pdlco_pd = [nips15.PatientData.from_tbl(tbl, **pdlco_spec) for _, tbl in pdlco.groupby('ptid')]

pv1_spec = {'t':'years_seen', 'y':'pfev1', 'x1':demographic, 'x2':demographic}
pv1 = pd.read_csv('data/benchmark_pv1.csv')
pv1_match = ['ptid'] + pv1_spec['x1']
pv1 = pd.merge(pfvc[pv1_match], pv1, 'left', pv1_match).drop_duplicates()
pv1_pd = [nips15.PatientData.from_tbl(tbl, **pv1_spec) for _, tbl in pv1.groupby('ptid')]

sp_spec = {'t':'years_seen', 'y':'rvsp', 'x1':demographic, 'x2':demographic}
sp = pd.read_csv('data/benchmark_sp.csv')
sp_match = ['ptid'] + sp_spec['x1']
sp = pd.merge(pfvc[sp_match], sp, 'left', sp_match).drop_duplicates()
sp_pd = [nips15.PatientData.from_tbl(tbl, **sp_spec) for _, tbl in sp.groupby('ptid')]

# %%
get_ptids = lambda pd: [p.ptid for p in pd]
pfvc_df   = pd.DataFrame({'ptid': get_ptids(pfvc_pd),  'pfvc' : pfvc_pd}).set_index('ptid')
tss_df    = pd.DataFrame({'ptid': get_ptids(tss_pd),   'tss'  : tss_pd}).set_index('ptid')
pdlco_df  = pd.DataFrame({'ptid': get_ptids(pdlco_pd), 'pdlco': pdlco_pd}).set_index('ptid')
pv1_df    = pd.DataFrame({'ptid': get_ptids(pv1_pd),   'pv1'  : pv1_pd}).set_index('ptid')
sp_df     = pd.DataFrame({'ptid': get_ptids(sp_pd),    'rvsp' : sp_pd}).set_index('ptid')

# %%
folds_df = pfvc.loc[:, ['ptid', 'fold']].drop_duplicates().set_index('ptid')

# %%
patient_data = pd.concat([folds_df, pfvc_df, tss_df, pdlco_df, pv1_df, sp_df], axis=1, join='inner')

# %%
def make_examples(patient_data, col_names, models, censor_time, aux_censor=None):
    marker_histories = zip(*[patient_data[n] for n in col_names])
    examples = []
    for i, histories in enumerate(marker_histories):
        X = []
        for j, h in enumerate(histories):
            if j > 0 and aux_censor is not None:
                d_obs = h.truncate(aux_censor).unpack()
            else:
                d_obs = h.truncate(censor_time).unpack()
            X.append(d_obs)
            
        X_unobs = []
        for j, (m, h) in enumerate(zip(models, histories)):
            if j > 0 and aux_censor is not None:
                d_unobs = h.truncate(aux_censor, after=True).unpack()
            else:
                d_unobs = h.truncate(censor_time, after=True).unpack()
                
            X_unobs.append(d_unobs)
            
        p = models[0].posterior(*histories[0].unpack())
        y_hat = np.argmax(p)
        
        y = (y_hat, X_unobs)
            
        ex = (X, y)
        examples.append(ex)
        
    return examples

# %%
import imp
imp.reload(loglin)
from mypy.util import check_grad

import lbfgs

import logging; imp.reload(logging)
from scipy.optimize import minimize
logging.basicConfig(level=logging.INFO)

# %% [markdown]
# model_posteriors = np.zeros((patient_data.shape[0], 8))
# np.savetxt('param/model_posteriors.dat', model_posteriors)

# %%
model_names = ['pfvc', 'tss', 'pdc', 'pv1']
col_names   = ['pfvc', 'tss', 'pdlco', 'pv1']

censor = 1.0
folds = [k + 1 for k in range(10)]
max_iterations = 25
penalty = 1e-4

model_posteriors = np.zeros((patient_data.shape[0], 8))
posteriors_file = 'param/l1_full_hac_model_posteriors_{:.01e}'.format(penalty)
np.savetxt(posteriors_file, model_posteriors)

all_models = []

for fold in folds:
    print('Starting fold {}'.format(fold))
    
    model_posteriors = np.loadtxt(posteriors_file)
    
    models = [load_model(m, fold) for m in model_names]
    test = patient_data['fold'].values == fold
    train = ~test

    train_data = make_examples(patient_data[train], col_names, models, censor, censor)
    test_data = make_examples(patient_data[test], col_names, models, censor, censor)

    model = loglin.SubtypeModel(penalty, models, censor, regularizer='l1', max_iterations=max_iterations)
    model.fit(train_data)
    
    all_models.append(model)

    model_posteriors[test, :] = model.proba([X for X, _ in test_data])
    np.savetxt(posteriors_file, model_posteriors)
# Out:
# INFO:root:Evaluated objective: f(w) = 26.35695883, ||w||_0 = 326
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.05267351
# INFO:root:Evaluated objective: f(w) = 26.15758196, ||w||_0 = 321
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02191881
# INFO:root:Evaluated objective: f(w) = 26.12903140, ||w||_0 = 321
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.06415875
# INFO:root:Evaluated objective: f(w) = 26.08930550, ||w||_0 = 324
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02101445
# INFO:root:Evaluated objective: f(w) = 26.07366697, ||w||_0 = 323
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02234525
# INFO:root:Evaluated objective: f(w) = 26.01737623, ||w||_0 = 316
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01831606
# INFO:root:Evaluated objective: f(w) = 25.97311013, ||w||_0 = 313
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00783914
# INFO:root:Evaluated objective: f(w) = 25.93337362, ||w||_0 = 315
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01281174
# INFO:root:Evaluated objective: f(w) = 25.97424856, ||w||_0 = 305
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.07515812
# INFO:root:Evaluated objective: f(w) = 25.93002931, ||w||_0 = 312
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.04731596
# INFO:root:Evaluated objective: f(w) = 25.90937217, ||w||_0 = 317
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.03207643
# INFO:root:Evaluated objective: f(w) = 25.89767789, ||w||_0 = 322
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00398781
# INFO:root:Evaluated objective: f(w) = 25.89389769, ||w||_0 = 323
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00463784
# INFO:root:Evaluated objective: f(w) = 25.87506930, ||w||_0 = 312
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01263569
# INFO:root:Evaluated objective: f(w) = 25.86577175, ||w||_0 = 310
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02400842
# INFO:root:Evaluated objective: f(w) = 25.85687508, ||w||_0 = 310
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00517799
# INFO:root:Evaluated objective: f(w) = 25.85133970, ||w||_0 = 312
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00623427
# INFO:root:Evaluated objective: f(w) = 25.84320328, ||w||_0 = 314
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00308877
# INFO:root:Evaluated objective: f(w) = 25.83456991, ||w||_0 = 304
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00737704
# INFO:root:Evaluated objective: f(w) = 25.82728200, ||w||_0 = 300
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00693782
# INFO:root:Evaluated objective: f(w) = 25.82216389, ||w||_0 = 308
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00499519
# INFO:root:Evaluated objective: f(w) = 25.81361098, ||w||_0 = 307
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01035508
# INFO:root:Evaluated objective: f(w) = 25.81468845, ||w||_0 = 303
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01993404
# INFO:root:Evaluated objective: f(w) = 25.80868856, ||w||_0 = 311
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00633122
# INFO:root:Evaluated objective: f(w) = 25.80419222, ||w||_0 = 302
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00523980
# INFO:root:Evaluated objective: f(w) = 25.79920272, ||w||_0 = 299
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00778372
# INFO:root:Evaluated objective: f(w) = 25.79481430, ||w||_0 = 302
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00451063
# INFO:root:Evaluated objective: f(w) = 25.78824051, ||w||_0 = 299
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00295238
# Starting fold 1
# Starting fold 2
# INFO:root:Evaluated objective: f(w) = 26.26935541, ||w||_0 = 326
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.05805989
# INFO:root:Evaluated objective: f(w) = 26.07107778, ||w||_0 = 321
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02653742
# INFO:root:Evaluated objective: f(w) = 26.04633670, ||w||_0 = 323
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.06642635
# INFO:root:Evaluated objective: f(w) = 26.00434905, ||w||_0 = 324
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01771482
# INFO:root:Evaluated objective: f(w) = 25.98938160, ||w||_0 = 324
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02535107
# INFO:root:Evaluated objective: f(w) = 25.93115277, ||w||_0 = 315
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02275045
# INFO:root:Evaluated objective: f(w) = 25.90742136, ||w||_0 = 310
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.06497174
# INFO:root:Evaluated objective: f(w) = 25.86664368, ||w||_0 = 317
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01884132
# INFO:root:Evaluated objective: f(w) = 25.85786863, ||w||_0 = 322
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01116977
# INFO:root:Evaluated objective: f(w) = 25.84205861, ||w||_0 = 321
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02027137
# INFO:root:Evaluated objective: f(w) = 25.81264799, ||w||_0 = 317
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02155888
# INFO:root:Evaluated objective: f(w) = 25.79988977, ||w||_0 = 319
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01713824
# INFO:root:Evaluated objective: f(w) = 25.78657403, ||w||_0 = 317
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00740751
# INFO:root:Evaluated objective: f(w) = 25.77377211, ||w||_0 = 313
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01208200
# INFO:root:Evaluated objective: f(w) = 25.76184968, ||w||_0 = 319
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00744895
# INFO:root:Evaluated objective: f(w) = 25.74044254, ||w||_0 = 313
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00594208
# INFO:root:Evaluated objective: f(w) = 25.73966047, ||w||_0 = 308
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02324373
# Starting fold 3
# INFO:root:Evaluated objective: f(w) = 26.42336446, ||w||_0 = 326
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.05927335
# INFO:root:Evaluated objective: f(w) = 26.20029188, ||w||_0 = 321
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02422217
# INFO:root:Evaluated objective: f(w) = 26.16987813, ||w||_0 = 322
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.06878631
# INFO:root:Evaluated objective: f(w) = 26.12525645, ||w||_0 = 324
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02177782
# INFO:root:Evaluated objective: f(w) = 26.10764532, ||w||_0 = 325
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02931749
# INFO:root:Evaluated objective: f(w) = 26.06670618, ||w||_0 = 320
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01612614
# INFO:root:Evaluated objective: f(w) = 25.98422352, ||w||_0 = 305
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01657239
# INFO:root:Evaluated objective: f(w) = 25.95321499, ||w||_0 = 312
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.03694367
# INFO:root:Evaluated objective: f(w) = 25.92960128, ||w||_0 = 321
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01145787
# INFO:root:Evaluated objective: f(w) = 25.92121525, ||w||_0 = 322
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01154143
# INFO:root:Evaluated objective: f(w) = 25.90571012, ||w||_0 = 318
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00818310
# INFO:root:Evaluated objective: f(w) = 25.89488943, ||w||_0 = 320
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01023620
# INFO:root:Evaluated objective: f(w) = 25.88055626, ||w||_0 = 314
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01440644
# INFO:root:Evaluated objective: f(w) = 25.86799568, ||w||_0 = 314
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01047697
# INFO:root:Evaluated objective: f(w) = 25.85734125, ||w||_0 = 317
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01602794
# INFO:root:Evaluated objective: f(w) = 25.84479357, ||w||_0 = 315
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01291928
# INFO:root:Evaluated objective: f(w) = 25.84040082, ||w||_0 = 306
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02049340
# INFO:root:Evaluated objective: f(w) = 25.82879304, ||w||_0 = 315
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00651388
# INFO:root:Evaluated objective: f(w) = 25.82463008, ||w||_0 = 317
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00674672
# INFO:root:Evaluated objective: f(w) = 25.80681822, ||w||_0 = 296
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00580151
# INFO:root:Evaluated objective: f(w) = 25.81684013, ||w||_0 = 298
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02671519
# INFO:root:Evaluated objective: f(w) = 25.80002966, ||w||_0 = 307
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00751226
# INFO:root:Evaluated objective: f(w) = 25.79502062, ||w||_0 = 308
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00372676
# INFO:root:Evaluated objective: f(w) = 25.78973920, ||w||_0 = 311
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00655301
# INFO:root:Evaluated objective: f(w) = 25.78461933, ||w||_0 = 303
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01005424
# INFO:root:Evaluated objective: f(w) = 25.78041020, ||w||_0 = 300
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00713874
# INFO:root:Evaluated objective: f(w) = 25.77658724, ||w||_0 = 303
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00490291
# Starting fold 4
# INFO:root:Evaluated objective: f(w) = 26.87951263, ||w||_0 = 326
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.05301406
# INFO:root:Evaluated objective: f(w) = 26.64929618, ||w||_0 = 321
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02639057
# INFO:root:Evaluated objective: f(w) = 26.59607297, ||w||_0 = 322
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.05123454
# INFO:root:Evaluated objective: f(w) = 26.56530056, ||w||_0 = 324
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02207096
# INFO:root:Evaluated objective: f(w) = 26.54700290, ||w||_0 = 324
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02551685
# INFO:root:Evaluated objective: f(w) = 26.46679454, ||w||_0 = 308
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02582802
# INFO:root:Evaluated objective: f(w) = 26.38487479, ||w||_0 = 311
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.03631640
# INFO:root:Evaluated objective: f(w) = 26.38307452, ||w||_0 = 308
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.04068807
# Starting fold 5
# INFO:root:Evaluated objective: f(w) = 26.99166720, ||w||_0 = 326
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.05721038
# INFO:root:Evaluated objective: f(w) = 26.75639747, ||w||_0 = 321
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02650106
# INFO:root:Evaluated objective: f(w) = 26.75077654, ||w||_0 = 322
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.09407231
# INFO:root:Evaluated objective: f(w) = 26.67568665, ||w||_0 = 325
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02241542
# INFO:root:Evaluated objective: f(w) = 26.66080686, ||w||_0 = 325
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02364775
# INFO:root:Evaluated objective: f(w) = 26.58803456, ||w||_0 = 314
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02378496
# INFO:root:Evaluated objective: f(w) = 26.54695741, ||w||_0 = 317
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.03101217
# INFO:root:Evaluated objective: f(w) = 26.52733415, ||w||_0 = 316
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.03926401
# INFO:root:Evaluated objective: f(w) = 26.50230789, ||w||_0 = 321
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01959836
# INFO:root:Evaluated objective: f(w) = 26.47870414, ||w||_0 = 317
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01165366
# INFO:root:Evaluated objective: f(w) = 26.54884548, ||w||_0 = 307
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.06941315
# INFO:root:Evaluated objective: f(w) = 26.45982555, ||w||_0 = 314
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02292001
# INFO:root:Evaluated objective: f(w) = 26.44390401, ||w||_0 = 321
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01011297
# INFO:root:Evaluated objective: f(w) = 26.43678381, ||w||_0 = 320
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00434766
# INFO:root:Evaluated objective: f(w) = 26.42784709, ||w||_0 = 321
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00829348
# INFO:root:Evaluated objective: f(w) = 26.41628059, ||w||_0 = 314
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00820471
# INFO:root:Evaluated objective: f(w) = 26.40440190, ||w||_0 = 315
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00920916
# INFO:root:Evaluated objective: f(w) = 26.39263523, ||w||_0 = 309
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00465043
# INFO:root:Evaluated objective: f(w) = 26.38033241, ||w||_0 = 308
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01164712
# INFO:root:Evaluated objective: f(w) = 26.36973025, ||w||_0 = 315
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00383348
# INFO:root:Evaluated objective: f(w) = 26.36116815, ||w||_0 = 310
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00404654
# INFO:root:Evaluated objective: f(w) = 26.35310175, ||w||_0 = 308
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00680083
# INFO:root:Evaluated objective: f(w) = 26.35242794, ||w||_0 = 306
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01543749
# Starting fold 6
# INFO:root:Evaluated objective: f(w) = 26.81201366, ||w||_0 = 326
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.05137319
# INFO:root:Evaluated objective: f(w) = 26.59345236, ||w||_0 = 321
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02326195
# INFO:root:Evaluated objective: f(w) = 26.55043588, ||w||_0 = 323
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.05158591
# INFO:root:Evaluated objective: f(w) = 26.52022125, ||w||_0 = 324
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02343953
# INFO:root:Evaluated objective: f(w) = 26.49634661, ||w||_0 = 322
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02476526
# INFO:root:Evaluated objective: f(w) = 26.43045207, ||w||_0 = 318
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01641077
# INFO:root:Evaluated objective: f(w) = 26.38731687, ||w||_0 = 310
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.03010089
# INFO:root:Evaluated objective: f(w) = 26.34603434, ||w||_0 = 311
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02156822
# INFO:root:Evaluated objective: f(w) = 26.31613234, ||w||_0 = 308
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02894712
# INFO:root:Evaluated objective: f(w) = 26.29915514, ||w||_0 = 321
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00588101
# INFO:root:Evaluated objective: f(w) = 26.29397460, ||w||_0 = 322
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00560623
# INFO:root:Evaluated objective: f(w) = 26.27230466, ||w||_0 = 313
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00603360
# INFO:root:Evaluated objective: f(w) = 26.27535892, ||w||_0 = 314
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02241855
# INFO:root:Evaluated objective: f(w) = 26.26596574, ||w||_0 = 316
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01130265
# INFO:root:Evaluated objective: f(w) = 26.25851044, ||w||_0 = 320
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01653372
# INFO:root:Evaluated objective: f(w) = 26.24889782, ||w||_0 = 320
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00436244
# INFO:root:Evaluated objective: f(w) = 26.24138006, ||w||_0 = 318
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00675992
# INFO:root:Evaluated objective: f(w) = 26.22292513, ||w||_0 = 306
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01106508
# INFO:root:Evaluated objective: f(w) = 26.21044665, ||w||_0 = 310
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01195982
# INFO:root:Evaluated objective: f(w) = 26.20303018, ||w||_0 = 314
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00471987
# INFO:root:Evaluated objective: f(w) = 26.19712011, ||w||_0 = 307
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00320659
# INFO:root:Evaluated objective: f(w) = 26.19065967, ||w||_0 = 315
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00558133
# INFO:root:Evaluated objective: f(w) = 26.18887365, ||w||_0 = 319
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01464494
# Starting fold 7
# INFO:root:Evaluated objective: f(w) = 25.24231514, ||w||_0 = 326
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.04961935
# INFO:root:Evaluated objective: f(w) = 25.02009206, ||w||_0 = 321
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02251666
# INFO:root:Evaluated objective: f(w) = 25.00484680, ||w||_0 = 320
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.08154942
# INFO:root:Evaluated objective: f(w) = 24.95221179, ||w||_0 = 323
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02350858
# INFO:root:Evaluated objective: f(w) = 24.93909056, ||w||_0 = 325
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02239466
# INFO:root:Evaluated objective: f(w) = 24.88789027, ||w||_0 = 318
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01720155
# INFO:root:Evaluated objective: f(w) = 24.84801496, ||w||_0 = 317
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00967649
# INFO:root:Evaluated objective: f(w) = 24.81087972, ||w||_0 = 317
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00883006
# INFO:root:Evaluated objective: f(w) = 24.78959152, ||w||_0 = 302
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02765563
# INFO:root:Evaluated objective: f(w) = 24.75933644, ||w||_0 = 315
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01067237
# INFO:root:Evaluated objective: f(w) = 24.75508542, ||w||_0 = 321
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01371919
# INFO:root:Evaluated objective: f(w) = 24.74735718, ||w||_0 = 318
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00838699
# INFO:root:Evaluated objective: f(w) = 24.73793984, ||w||_0 = 321
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00678788
# INFO:root:Evaluated objective: f(w) = 24.72603497, ||w||_0 = 321
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00818555
# INFO:root:Evaluated objective: f(w) = 24.70893074, ||w||_0 = 317
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01219537
# INFO:root:Evaluated objective: f(w) = 24.69915719, ||w||_0 = 310
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01658988
# INFO:root:Evaluated objective: f(w) = 24.69193386, ||w||_0 = 317
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00642024
# INFO:root:Evaluated objective: f(w) = 24.68560134, ||w||_0 = 319
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00508658
# INFO:root:Evaluated objective: f(w) = 24.66793826, ||w||_0 = 314
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00591886
# INFO:root:Evaluated objective: f(w) = 24.68325464, ||w||_0 = 290
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.03007556
# INFO:root:Evaluated objective: f(w) = 24.65924630, ||w||_0 = 302
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01379029
# INFO:root:Evaluated objective: f(w) = 24.65027118, ||w||_0 = 302
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01031089
# INFO:root:Evaluated objective: f(w) = 24.64414324, ||w||_0 = 311
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00637286
# INFO:root:Evaluated objective: f(w) = 24.63678140, ||w||_0 = 310
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00720160
# INFO:root:Evaluated objective: f(w) = 24.62956613, ||w||_0 = 295
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00978341
# INFO:root:Evaluated objective: f(w) = 24.62492966, ||w||_0 = 306
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00627268
# INFO:root:Evaluated objective: f(w) = 24.62092938, ||w||_0 = 307
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00240638
# Starting fold 8
# INFO:root:Evaluated objective: f(w) = 25.49161643, ||w||_0 = 326
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.04739973
# INFO:root:Evaluated objective: f(w) = 25.28533684, ||w||_0 = 320
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02389555
# INFO:root:Evaluated objective: f(w) = 25.35839849, ||w||_0 = 319
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.13086890
# INFO:root:Evaluated objective: f(w) = 25.24098538, ||w||_0 = 325
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.04839441
# INFO:root:Evaluated objective: f(w) = 25.21407927, ||w||_0 = 322
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01962991
# INFO:root:Evaluated objective: f(w) = 25.19138157, ||w||_0 = 325
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02846381
# INFO:root:Evaluated objective: f(w) = 25.13416500, ||w||_0 = 317
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00847218
# INFO:root:Evaluated objective: f(w) = 25.07800300, ||w||_0 = 307
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.03477246
# INFO:root:Evaluated objective: f(w) = 25.05768008, ||w||_0 = 313
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02273867
# INFO:root:Evaluated objective: f(w) = 25.04526365, ||w||_0 = 317
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00953661
# INFO:root:Evaluated objective: f(w) = 25.01905216, ||w||_0 = 313
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01693791
# INFO:root:Evaluated objective: f(w) = 25.00518629, ||w||_0 = 311
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02255294
# INFO:root:Evaluated objective: f(w) = 24.99443270, ||w||_0 = 316
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00938403
# INFO:root:Evaluated objective: f(w) = 24.98525322, ||w||_0 = 317
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00729221
# INFO:root:Evaluated objective: f(w) = 24.97409233, ||w||_0 = 311
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01528378
# INFO:root:Evaluated objective: f(w) = 24.96313086, ||w||_0 = 318
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00459035
# INFO:root:Evaluated objective: f(w) = 24.95439654, ||w||_0 = 316
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00387200
# INFO:root:Evaluated objective: f(w) = 24.93704455, ||w||_0 = 299
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00510604
# INFO:root:Evaluated objective: f(w) = 24.92498780, ||w||_0 = 307
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01432921
# INFO:root:Evaluated objective: f(w) = 24.91635965, ||w||_0 = 306
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01859978
# INFO:root:Evaluated objective: f(w) = 24.90739933, ||w||_0 = 306
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00806037
# INFO:root:Evaluated objective: f(w) = 24.90079051, ||w||_0 = 306
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00465778
# INFO:root:Evaluated objective: f(w) = 24.89194421, ||w||_0 = 306
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00412071
# INFO:root:Evaluated objective: f(w) = 24.94867709, ||w||_0 = 289
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.06006641
# INFO:root:Evaluated objective: f(w) = 24.89287494, ||w||_0 = 301
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02226331
# INFO:root:Evaluated objective: f(w) = 24.88635704, ||w||_0 = 308
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00766894
# INFO:root:Evaluated objective: f(w) = 24.87726069, ||w||_0 = 303
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00908495
# INFO:root:Evaluated objective: f(w) = 24.87645312, ||w||_0 = 304
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01521848
# Starting fold 9
# INFO:root:Evaluated objective: f(w) = 26.83267680, ||w||_0 = 326
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.05992763
# INFO:root:Evaluated objective: f(w) = 26.59428989, ||w||_0 = 321
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02774203
# INFO:root:Evaluated objective: f(w) = 26.54972169, ||w||_0 = 321
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.05981741
# INFO:root:Evaluated objective: f(w) = 26.51153483, ||w||_0 = 325
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01992701
# INFO:root:Evaluated objective: f(w) = 26.49153927, ||w||_0 = 323
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02661579
# INFO:root:Evaluated objective: f(w) = 26.43156123, ||w||_0 = 319
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01988488
# INFO:root:Evaluated objective: f(w) = 26.38428759, ||w||_0 = 308
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.04160583
# INFO:root:Evaluated objective: f(w) = 26.34843807, ||w||_0 = 319
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02678812
# INFO:root:Evaluated objective: f(w) = 26.31743964, ||w||_0 = 322
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01341165
# INFO:root:Evaluated objective: f(w) = 26.27912868, ||w||_0 = 316
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01599662
# INFO:root:Evaluated objective: f(w) = 26.25502975, ||w||_0 = 318
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00945222
# INFO:root:Evaluated objective: f(w) = 26.24080122, ||w||_0 = 313
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01051755
# INFO:root:Evaluated objective: f(w) = 26.22772897, ||w||_0 = 315
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01012960
# INFO:root:Evaluated objective: f(w) = 26.21487585, ||w||_0 = 315
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01066732
# INFO:root:Evaluated objective: f(w) = 26.20227142, ||w||_0 = 316
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01810930
# INFO:root:Evaluated objective: f(w) = 26.18256071, ||w||_0 = 310
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00876649
# INFO:root:Evaluated objective: f(w) = 26.17330376, ||w||_0 = 315
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01570450
# INFO:root:Evaluated objective: f(w) = 26.16473826, ||w||_0 = 317
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00579946
# INFO:root:Evaluated objective: f(w) = 26.15869188, ||w||_0 = 315
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00399957
# INFO:root:Evaluated objective: f(w) = 26.14989395, ||w||_0 = 311
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00576896
# INFO:root:Evaluated objective: f(w) = 26.14730397, ||w||_0 = 308
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02108882
# INFO:root:Evaluated objective: f(w) = 26.13821417, ||w||_0 = 308
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00408695
# INFO:root:Evaluated objective: f(w) = 26.13502146, ||w||_0 = 312
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00289884
# INFO:root:Evaluated objective: f(w) = 26.12807895, ||w||_0 = 306
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00497532
# INFO:root:Evaluated objective: f(w) = 26.12708015, ||w||_0 = 298
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01038610
# Starting fold 10
# INFO:root:Evaluated objective: f(w) = 26.56936938, ||w||_0 = 326
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.05594202
# INFO:root:Evaluated objective: f(w) = 26.32807044, ||w||_0 = 321
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02929011
# INFO:root:Evaluated objective: f(w) = 26.27771504, ||w||_0 = 322
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.06034099
# INFO:root:Evaluated objective: f(w) = 26.24133681, ||w||_0 = 323
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02265089
# INFO:root:Evaluated objective: f(w) = 26.22248621, ||w||_0 = 325
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02688439
# INFO:root:Evaluated objective: f(w) = 26.15876353, ||w||_0 = 315
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02656212
# INFO:root:Evaluated objective: f(w) = 26.10409303, ||w||_0 = 309
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.04886804
# INFO:root:Evaluated objective: f(w) = 26.04892002, ||w||_0 = 311
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.04166992
# INFO:root:Evaluated objective: f(w) = 26.02961643, ||w||_0 = 321
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.02194196
# INFO:root:Evaluated objective: f(w) = 26.01141975, ||w||_0 = 314
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00922108
# INFO:root:Evaluated objective: f(w) = 25.99611884, ||w||_0 = 322
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01109428
# INFO:root:Evaluated objective: f(w) = 25.97869881, ||w||_0 = 319
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01051245
# INFO:root:Evaluated objective: f(w) = 25.97179397, ||w||_0 = 305
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.04461081
# INFO:root:Evaluated objective: f(w) = 25.94500119, ||w||_0 = 316
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00679880
# INFO:root:Evaluated objective: f(w) = 25.93572827, ||w||_0 = 313
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01074194
# INFO:root:Evaluated objective: f(w) = 25.92182509, ||w||_0 = 315
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00912974
# INFO:root:Evaluated objective: f(w) = 25.90384057, ||w||_0 = 320
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00941959
# INFO:root:Evaluated objective: f(w) = 25.89321187, ||w||_0 = 312
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.01532326
# INFO:root:Evaluated objective: f(w) = 25.88212039, ||w||_0 = 315
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00646429
# INFO:root:Evaluated objective: f(w) = 25.87782508, ||w||_0 = 316
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00440555
# INFO:root:Evaluated objective: f(w) = 25.87359078, ||w||_0 = 315
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00321448
# INFO:root:Evaluated objective: f(w) = 25.86846416, ||w||_0 = 310
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00672354
# INFO:root:Evaluated objective: f(w) = 25.86334734, ||w||_0 = 309
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00648621
# INFO:root:Evaluated objective: f(w) = 25.85908396, ||w||_0 = 307
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00846715
# INFO:root:Evaluated objective: f(w) = 25.85486057, ||w||_0 = 310
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00434839
# INFO:root:Evaluated objective: f(w) = 25.85022398, ||w||_0 = 308
# INFO:root:Evaluated gradient: ||g(w)||_inf = 0.00457867

# %%
posterior_tbl = pd.DataFrame(model_posteriors)
posterior_tbl.index = patient_data.index
posterior_tbl.columns = ['p{}'.format(i) for i in range(1, 9)]

# %%
posterior_tbl.to_csv('l1_full_hac_lgln_posteriors_{:.01e}.csv'.format(penalty))
